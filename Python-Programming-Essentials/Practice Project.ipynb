# %% [markdown]
# # Rock-Paper-Scissors-Lizard-Spock

# %%
"""
Week 4 practice project template for Python Programming Essentials
Rock-paper-scissors-lizard-Spock
"""

import random

# The key idea of this program is to equate the strings
# "rock", "paper", "scissors", "lizard", "Spock" to numbers
# as follows:
#
# 0 - rock
# 1 - Spock
# 2 - paper
# 3 - lizard
# 4 - scissors

# helper functions
    
def name_to_number(name):
    """
    Given string name, return integer 0, 1, 2, 3, or 4 
    corresponding to numbering in video
    """
  
    # convert name to number using if/elif/else
    # don't forget to return the result!
    
    if name == 'rock':
        return 0
    elif name == 'Spock':
        return 1
    elif name == 'paper':
        return 2
    elif name == 'lizard':
        return 3
    elif name == 'scissors':
        return 4
    else:
        pass
    
def number_to_name(number):
    """
    Given integer number (0, 1, 2, 3, or 4)
    corresponding name from video
    """
    
    # convert number to a name using if/elif/else
    # don't forget to return the result!
    
    if number == 0:
        return 'rock'
    elif number == 1:
        return 'Spock'
    elif number == 2:
        return 'paper'
    elif number == 3:
        return 'lizard'
    elif number == 4:
        return 'scissors'
    else:
        pass


def rpsls(player_choice):
    """
    Given string player_choice, play a game of RPSLS 
    and print results to console
    """
    
    # print a blank line to separate consecutive games
    
    # print out the message for the player's choice

    # convert the player's choice to player_number using the function name_to_number()

    # compute random guess for comp_number using random.randrange()

    # convert comp_number to comp_choice using the function number_to_name()
    
    # print out message for computer's choice

    # compute difference of player_number and comp_number modulo five

    # use if/elif/else to determine winner and print winner message
    
    player = name_to_number(player_choice)
    computer = random.randrange(5)
    
    if player == 0 and computer in [3,4]:
        statement = f'Player choose {player_choice}\nComputer choose {number_to_name(computer)}\nPlayer wins!'
        print(statement)
    elif player == 1 and computer in [0,4]:
        statement = f'Player choose {player_choice}\nComputer choose {number_to_name(computer)}\nPlayer wins!'
        print(statement)
    elif player == 2 and computer in [0,1]:
        statement = f'Player choose {player_choice}\nComputer choose {number_to_name(computer)}\nPlayer wins!'
        print(statement)
    elif player == 3 and computer in [2,1]:
        statement = f'Player choose {player_choice}\nComputer choose {number_to_name(computer)}\nPlayer wins!'
        print(statement)
    elif player == 4 and computer in [3,2]:
        statement = f'Player choose {player_choice}\nComputer choose {number_to_name(computer)}\nPlayer wins!'
        print(statement)
    elif player == 0 and computer in [2,1]:
        statement = f'Player choose {player_choice}\nComputer choose {number_to_name(computer)}\nComputer wins!'
        print(statement)
    elif player == 1 and computer in [2,3]:
        statement = f'Player choose {player_choice}\nComputer choose {number_to_name(computer)}\nComputer wins!'
        print(statement)
    elif player == 2 and computer in [3,4]:
        statement = f'Player choose {player_choice}\nComputer choose {number_to_name(computer)}\nComputer wins!'
        print(statement)
    elif player == 3 and computer in [4,0]:
        statement = f'Player choose {player_choice}\nComputer choose {number_to_name(computer)}\nComputer wins!'
        print(statement)
    elif player == 4 and computer in [0,1]:
        statement = f'Player choose {player_choice}\nComputer choose {number_to_name(computer)}\nComputer wins!'
        print(statement)
    else:
        print('There is a tie')
    print()
    
# test your code
rpsls("rock")
rpsls("Spock")
rpsls("paper")
rpsls("lizard")
rpsls("scissors")
rpsls(input('Introduce tu elección: '))
rpsls(input('Elige y pierde contra la máquina: '))

# always remember to check your completed program against the grading rubric
# Out:
# Player choose rock
# Computer choose lizard
# Player wins!
#
# Player choose Spock
# Computer choose rock
# Player wins!
#
# There is a tie
#
# There is a tie
#
# Player choose scissors
# Computer choose paper
# Player wins!
# Introduce tu elección:  rock
# Player choose rock
# Computer choose paper
# Computer wins!
# Wavis, elige y pierde contra la máquina:  Spock
# Player choose Spock
# Computer choose paper
# Computer wins!
